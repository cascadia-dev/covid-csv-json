# %%
import pandas as pd

def get_covid_dataframe_for_date(date):
    df0 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/"+date+".csv");
    df=df0.loc[(df0['Province_State'] == 'Washington')]
    dfs=df[['Admin2','Confirmed','Deaths']]
    dfs=dfs.rename(columns={"Admin2": "County"})
    #dfs.index=dfs['County'] #new
    #dfs.drop(columns='County',inplace=True)
    dfs['date']=date
    return dfs.set_index(['County','date'])

dates=['03-22-2020','03-23-2020','03-24-2020','03-25-2020']
frames = [ get_covid_dataframe_for_date(d) for d in dates ]

# %%
pp=pd.concat(frames)
pp
# Out:
#                         Confirmed  Deaths
# County      date
# King        03-22-2020       1040      75
# Snohomish   03-22-2020        480      10
# Unassigned  03-22-2020        164       0
# Pierce      03-22-2020        107       1
# Skagit      03-22-2020         33       0
# ...                           ...     ...
# Wahkiakum   03-25-2020          0       0
# Walla Walla 03-25-2020          2       0
# Whatcom     03-25-2020         64       2
# Whitman     03-25-2020          2       0
# Yakima      03-25-2020         47       1
#
# [162 rows x 2 columns]
