# %%
import pandas as pd

df_confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")
df_deaths = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv")

# %%
df_confirmed_wa = df_confirmed.loc[(df_confirmed['Province/State'] == 'Washington')]
df_deaths_wa = df_deaths.loc[(df_deaths['Province/State'] == 'Washington')]

# %%
df_deaths_wa=df_deaths_wa.rename(index={98: "Deaths"})
df_deaths_wa=df_deaths_wa.transpose().drop(index={'Lat','Long','Province/State','Country/Region'})

# %%
df_confirmed_wa=df_confirmed_wa.rename(index={98: "Confirmed"})
df_confirmed_wa=df_confirmed_wa.transpose().drop(index={'Lat','Long','Province/State','Country/Region'})

# %%
df_combined_wa=df_confirmed_wa.join(df_deaths_wa)

# %%
df_combined_wa.index=pd.to_datetime(df_combined_wa.index)
df_combined_wa
# Out:
#            Confirmed Deaths
# 2020-01-22         0      0
# 2020-01-23         0      0
# 2020-01-24         0      0
# 2020-01-25         0      0
# 2020-01-26         0      0
# ...              ...    ...
# 2020-03-19      1376     74
# 2020-03-20      1524     83
# 2020-03-21      1793     94
# 2020-03-22      1996     95
# 2020-03-23      1996     95
#
# [62 rows x 2 columns]

# %%
df_combined_wa['date']=df_combined_wa.index.to_series().dt.strftime("%Y-%m-%d")
df_combined_wa[['date','Confirmed','Deaths']].to_json(orient='values')
# Out:
# '[["2020-01-22",0,0],["2020-01-23",0,0],["2020-01-24",0,0],["2020-01-25",0,0],["2020-01-26",0,0],["2020-01-27",0,0],["2020-01-28",0,0],["2020-01-29",0,0],["2020-01-30",0,0],["2020-01-31",0,0],["2020-02-01",0,0],["2020-02-02",0,0],["2020-02-03",0,0],["2020-02-04",0,0],["2020-02-05",0,0],["2020-02-06",0,0],["2020-02-07",0,0],["2020-02-08",0,0],["2020-02-09",0,0],["2020-02-10",0,0],["2020-02-11",0,0],["2020-02-12",0,0],["2020-02-13",0,0],["2020-02-14",0,0],["2020-02-15",0,0],["2020-02-16",0,0],["2020-02-17",0,0],["2020-02-18",0,0],["2020-02-19",0,0],["2020-02-20",0,0],["2020-02-21",0,0],["2020-02-22",0,0],["2020-02-23",0,0],["2020-02-24",0,0],["2020-02-25",0,0],["2020-02-26",0,0],["2020-02-27",0,0],["2020-02-28",0,0],["2020-02-29",0,0],["2020-03-01",0,0],["2020-03-02",0,0],["2020-03-03",0,0],["2020-03-04",0,0],["2020-03-05",0,0],["2020-03-06",0,0],["2020-03-07",0,0],["2020-03-08",0,0],["2020-03-09",0,0],["2020-03-10",267,23],["2020-03-11",366,29],["2020-03-12",442,31],["2020-03-13",568,
# ...
